# %%
import os
import time
from random import random
import tweepy as tp
import jsonpickle

import json
import sys
import string
import re
import us
import simplejson
from twython import Twython
from textblob import TextBlob
import matplotlib
import matplotlib.pyplot as plt

from datetime import datetime, date, time, timedelta
from dateutil import parser as dateparser
from collections import Counter

# %%
consumer_key = 'D44YmpJEtFioaZkYmXWJ8hwc8'
consumer_secret = 'LekWYdSHt2XJ5yr7HOEK7i560kqhWDVXzuxesdJr9rLgwtr5SF'
access_token = '51341945-pgnokFwr0dQrlVXfiAgdxceW3rJiZxr0AO02ildib'
access_secret = 'RLAVqW3sF7nTaBWhAetxC5VagMvxNsbsZiCt1nHuq01it'

# %% [markdown]
# # Collecting Data through Twitter API

# %%
# login to twitter account api
auth = tp.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tp.API(auth, wait_on_rate_limit=True)

# %%
#https://labsblog.f-secure.com/2018/01/26/how-to-get-tweets-from-a-twitter-account-using-python-and-tweepy/
def acquire_tweet_data(accounts, full_API, selected_features):
    if len(accounts) > 0:
        for target in accounts:
            print("Getting data for " + target)
            item = api.get_user(target)
            #aggregated_tweet_data_full contains the entire json from the Twitter API
            full_API[target] = item
            #aggregated_tweet_data_selected contains selected features
            selected_features[target] = {}
            selected_features[target]['name'] = item.name
            selected_features[target]['screen_name'] = item.screen_name
            selected_features[target]['description'] = item.description
            selected_features[target]['statuses_count'] = item.statuses_count
            selected_features[target]['friends_count'] = item.friends_count
            selected_features[target]['followers_count'] = item.followers_count

            print("name: " + item.name)
            print("screen_name: " + item.screen_name)
            print("description: " + item.description)
            print("statuses_count: " + str(item.statuses_count))
            print("friends_count: " + str(item.friends_count))
            print("followers_count: " + str(item.followers_count))

            #Average Tweets per day
            tweets = item.statuses_count
            account_created_date = item.created_at
            delta = datetime.utcnow() - account_created_date
            account_age_days = delta.days
            print("Account age (in days): " + str(account_age_days))
            if account_age_days > 0:
                print("Average tweets per day: " + "%.2f"%(float(tweets)/float(account_age_days)))
                average_tweet_per_day = (float(tweets)/float(account_age_days))
            #add to aggregated_tweet_data_selected
            selected_features[target]['Account_age(in_days)'] = account_age_days
            selected_features[target]['average_tweet_per_day'] = average_tweet_per_day

            #hashtags, mentions, tweet count, and statuses
            hashtags = []
            mentions = []
            tweet_count = 0
            statuses = []
            end_date = datetime.utcnow() - timedelta(days=365)
            for status in tp.Cursor(api.user_timeline, id=target).items():
                statuses.append({"retweeted": status.retweeted, "created_at": status.created_at.hour, "text": status.text, "entities": status.entities})
                tweet_count += 1
                if hasattr(status, "entities"):
                    entities = status.entities
                if "hashtags" in entities:
                    for ent in entities["hashtags"]:
                        if ent is not None:
                            if "text" in ent:
                                hashtag = ent["text"]
                        if hashtag is not None:
                            hashtags.append(hashtag)
                if "user_mentions" in entities:
                    for ent in entities["user_mentions"]:
                        if ent is not None:
                            if "screen_name" in ent:
                                name = ent["screen_name"]
                        if name is not None:
                            mentions.append(name)
                            
            #add to aggregated_tweet_data_selected
            selected_features[target]['hashtags'] = hashtags
            selected_features[target]['mentions'] = mentions
            selected_features[target]['tweet_count'] = tweet_count
            selected_features[target]['statuses'] = statuses

            #printing mentions, hashtags
            print("Most mentioned Twitter users:")
            for item, count in Counter(mentions).most_common(10):
                print(item + "\t" + str(count))

            print("Most used hashtags:")
            for item, count in Counter(hashtags).most_common(10):
                print(item + "\t" + str(count))

            print("All done. Processed " + str(tweet_count) + " tweets.")

# %% [markdown]
# # Depressed Users

# %%
#batch 1
 account_list = [ 'eyeamkyri', 'dreiguzman', 'philip_pholland','Nicole_Anderson', 
             'CuzValSays', 'WHATISAPLANET', 'AriannaCorona18', 'Mabbe17','depresstheshit','Zeusbear1987','mikemik46741501','SadGirlsClubIRL']

aggregated_tweet_data_full = {}
aggregated_tweet_data_selected = {}

#call function to acquire tweet data from Twitter API
acquire_tweet_data(account_list, aggregated_tweet_data_full, aggregated_tweet_data_selected)
# Out:
# Getting data for eyeamkyri
# name: Kyrì
# screen_name: eyeamkyri
# description: God created me to create. Job 42:2🦋 | MY SINGLE “EYE AM LOVE” IS AVAILABLE ON ALL PLATFORMS (link below) | for inquiries: ksmminquires@gmail.com
# statuses_count: 19983
# friends_count: 647
# followers_count: 2976
# Account age (in days): 1875
# Average tweets per day: 10.66
# Most mentioned Twitter users:
# eyeamkyri	187
# PremeTvinc	108
# beautyviajaleah	80
# sohollywood___	78
# TheyLoveMoodie	56
# MalenaPeaks	56
# xHoneyHendrix	55
# ItsJusticeV	40
# wyzeart	38
# Vonngocrazy	29
# Most used hashtags:
# ISRAELSTRONG	2
# ΑΦΑ	1
# GoBucks	1
# ToughLove	1
# NationalPhotographyDay	1
# CulturedByUgo	1
# saphshoots	1
# brownskingirl	1
# TheGiftAlbum	1
# BETAwards	1
# All done. Processed 3145 tweets.
# Getting data for dreiguzman
# name: drei (they/them)
# screen_name: dreiguzman
# description: i have half a braincell
# statuses_count: 8315
# friends_count: 209
# followers_count: 183
# Account age (in days): 434
# Average tweets per day: 19.16
# Most mentioned Twitter users:
# idasiasoco	132
# chescapersia	85
# ralphcapital_	80
# dmfrankku	66
# alexiacryze	65
# _gericortez	64
# lrakheinz	41
# tseyadz	28
# MeteoRoyD	28
# milkstrology	28
# Most used hashtags:
# GIVEAWAY	6
# NewProfilePic	5
# Inktober2019	5
# Inktober	4
# WalangPasok	4
# BenteOHNO	3
# Giveaway	3
# artph	2
# HBDMC	2
# InktoberDay2	2
# All done. Processed 3095 tweets.
# Getting data for philip_pholland
# name: Philip holland
# screen_name: philip_pholland
# description: its not about perfect, its about effort.
# statuses_count: 536
# friends_count: 37
# followers_count: 16
# Account age (in days): 2454
# Average tweets per day: 0.22
# Most mentioned Twitter users:
# JillianMichaels	203
# howisalan	30
# DavidQuickfall	28
# rickygervais	22
# KTHopkins	16
# MENnewsdesk	14
# pewdiepie	14
# GNev2	12
# Boogie2988	10
# MCRMetrolink	9
# Most used hashtags:
# WoodwardOut	1
# americasass	1
# slaverywasachoice	1
# hateuber	1
# manchesteruk	1
# sweat	1
# jillianmichaelsapp	1
# kickingass	1
# peasinapod	1
# strangeukgames	1
# All done. Processed 536 tweets.
# Getting data for Nicole_Anderson
# name: Nicole Anderson
# screen_name: Nicole_Anderson
# description: There is nothing more magical than that moment right as the lights go down and the crowd is waiting in silence with anticipation for the show to begin🎶🎭
# statuses_count: 26651
# friends_count: 49
# followers_count: 442
# Account age (in days): 3883
# Average tweets per day: 6.86
# Most mentioned Twitter users:
# JadeMcBride13	169
# aimeestewart187	55
# Lin_Manuel	49
# Nicole_Anderson	43
# Machinexo	30
# sixthemusical	27
# HamiltonMusical	22
# JeremyMJordan	22
# GillianLyn_W	22
# alanhmcdonald	21
# Most used hashtags:
# disney	30
# harleyquinn	21
# comiccon	16
# disneylandparis	15
# suicidesquad	15
# halloween	13
# cosplay	13
# boyfriend	13
# disneylandparis25	12
# hamilton	10
# All done. Processed 3197 tweets.
# Getting data for CuzValSays
# name: VarleyQuinn♦️
# screen_name: CuzValSays
# description: SC: cuzvalsays. I'm more active there. Aspiring boss lady. Future Best Seller .WWE. Harley Quinn. 26. #Taken #SethRollins #CMPunk #AJLee AJ RT'D 10/31/14
# statuses_count: 28152
# friends_count: 1558
# followers_count: 1497
# Account age (in days): 3539
# Average tweets per day: 7.95
# Most mentioned Twitter users:
# Tio_Horchata	59
# CuzValSays	38
# WWERollins	33
# CMPunk	28
# WWEAJLee	27
# Tony_TC10	24
# HeelDELB	22
# Heel4Lif3	19
# WrestlingLAD	17
# WWE	16
# Most used hashtags:
# SummerSlam	114
# RAW	80
# WWE	43
# RoyalRumble	42
# WrestleMania	37
# WWEHIAC	26
# AmbrosevsRollins	26
# HIAC	24
# WWETLC	20
# SurvivorSeries	17
# All done. Processed 2943 tweets.
# Getting data for WHATISAPLANET
# name: WHAT IS A PLANET
# screen_name: WHATISAPLANET
# description: i know i shouldn't really be here
# statuses_count: 481234
# friends_count: 0
# followers_count: 566
# Account age (in days): 1696
# Average tweets per day: 283.75
# Most mentioned Twitter users:
# 1blessedbee	1
# Most used hashtags:
# All done. Processed 3216 tweets.
# Getting data for AriannaCorona18
# name: Arianna Corona
# screen_name: AriannaCorona18
# description: 15 years old. Not the best at being emotionally stable, but I love myself.💗 Blackbear and other chill music are my fav.
# statuses_count: 19
# friends_count: 95
# followers_count: 7
# Account age (in days): 745
# Average tweets per day: 0.03
# Most mentioned Twitter users:
# QuoteNiLuffy	6
# iamblackbear	4
# PHORAONE	2
# KardashianNavy	1
# Most used hashtags:
# All done. Processed 15 tweets.
# Getting data for Mabbe17
# name: Mi
# screen_name: Mabbe17
# description: no straw no problem
# statuses_count: 6159
# friends_count: 454
# followers_count: 499
# Account age (in days): 2120
# Average tweets per day: 2.91
# Most mentioned Twitter users:
# rf_wil	298
# D_God__	175
# Mabbe17	133
# addiersmith	44
# oliviacsaki0	42
# csolar_	36
# jamescharles	35
# Madison1624N	34
# z_handlin20	29
# tieramorriss	25
# Most used hashtags:
# NewProfilePic	10
# LivingWithDepressionIs	3
# 4WordStoryOfMyLife	2
# FocusOnFour	2
# wcw	2
# OurTimeIsNow	1
# WinDominosPizza	1
# NationalPizzaMonth	1
# CollegeInSixWords	1
# WorldSuicidePreventionDay	1
# All done. Processed 2858 tweets.
# Getting data for depresstheshit
# name: depressing
# screen_name: depresstheshit
# description: Depressing Quotes - From the heart
# statuses_count: 21
# friends_count: 0
# followers_count: 4
# Account age (in days): 4
# Average tweets per day: 5.25
# Most mentioned Twitter users:
# OlSaintN1CK	1
# SexyPillowsPC	1
# Most used hashtags:
# depressing	7
# depressed	6
# depressingquotes	6
# All done. Processed 21 tweets.
# Getting data for Zeusbear1987
# name: Dean Edwards
# screen_name: Zeusbear1987
# description: Sometimes I tweet about The Walking Dead, sometimes I don't.
# statuses_count: 1008
# friends_count: 440
# followers_count: 28
# Account age (in days): 2123
# Average tweets per day: 0.47
# Most mentioned Twitter users:
# Meg_Stansfield	39
# UberFacts	32
# WalkingDead_AMC	28
# MurrellDan	27
# JTEmoviethinks	26
# joestarr187	25
# April13Dawn	25
# andysignore	21
# TheWalkingDead	21
# screenjunkies	19
# Most used hashtags:
# TheWalkingDead	36
# TWDFamily	14
# MiddleAgedSchmovies	11
# TheWalkingDeadUK	10
# MovieFights	7
# schmoedown	4
# TrickorTreatTCB	4
# FreeTrev	4
# TWD	3
# TheWalkingDeadTONIGHT	3
# All done. Processed 992 tweets.
# Getting data for mikemik46741501
# name: mikemike💪🏽
# screen_name: mikemik46741501
# description: 🗣✍🏽
# statuses_count: 25
# friends_count: 1
# followers_count: 0
# Account age (in days): 32
# Average tweets per day: 0.78
# Most mentioned Twitter users:
# LaTiffany12	4
# reibesos	1
# Most used hashtags:
# depressed	1
# All done. Processed 25 tweets.
# Getting data for SadGirlsClubIRL
# name: Sad Girls Club
# screen_name: SadGirlsClubIRL
# description: @SadGirlsClub on Instagram. hi@sadgirlsclub.org
# statuses_count: 632
# friends_count: 26
# followers_count: 1336
# Account age (in days): 928
# Average tweets per day: 0.68
# Most mentioned Twitter users:
# Elyse__Fox	144
# SadGirlsClubIRL	133
# broadly	20
# pinkprotest	11
# scarcurtis	10
# fox5ny	8
# instagram	7
# AmaniRakeia	6
# theGirlMob	6
# ShiraBTherapy	6
# Most used hashtags:
# ShortyAwards	12
# mentalhealth	7
# WorldMentalHealthDay	5
# mentalhealthawarenessmonth	5
# HereForYou	4
# selfcare	3
# repost	2
# InternationalWomensDay	2
# MentalHealthAwarenessWeek	2
# TGMDay2018	2
# All done. Processed 623 tweets.

# %% [markdown]
# # Non-Depressed Users

# %%
ND_account_list = ['BryanHabana', 'OnigiriVal', 'ChrisLeeTM', 'derinhwillcox', 'DougArmstrong', 'ErikaHarlacher',
                  'rightnowlouis', 'abidavisf', 'Lauryn_Houseman', 'trainershanna', 
                   'BarackObama', 'pigskinpug', 'marwilliamson', 'neiltyson', 'BillNye','eunhae_sjbabies', 'EvaLongoria', 
                   'shafenoni', 'maddyb_10', 'RachelBLevinson', 'CarryMinati', 'ethanesquick', 'mlota_azola',
                  'AceNcobo', 'WeLuvAllyB', 'Juliannadago', '2Saintt', 'katyperry', 'XUKUNlSM', 'emNikhil',
                   'Miss_Arilicious', 'ashchanchlani', 'LoganPaul', 'TheTeawrex', 'loveonlycr', 'GerberKawasaki',
                   'aprilwensel', 'Smatterbrain', 'AtomicRy', 'jackieepelayo','antoinetterrrz', 'EstherThePig',
                   'jessiepaege', 'LeVeonBell', 'Casey', 'MrBeastYT', 'AyoDaewon', 'alexarodrigguez',
                   'NYGiantsRush', 'RareAccount','jakepaul', 'christiand', 'Frogiiii', 'lelepons',
                   'CollinsKey', 'allmainlin', 'Dwilliams1515', 'JohnLegere', 'EthanDolan', 'RomanAtwood']

ND_aggregated_tweet_data_full = {}
ND_aggregated_tweet_data_selected = {}

#call function to acquire tweet data from Twitter API
acquire_tweet_data(ND_account_list, ND_aggregated_tweet_data_full, ND_aggregated_tweet_data_selected)
# Out:
# Getting data for BryanHabana
# name: Bryan Habana
# screen_name: BryanHabana
# description: Proud South African. Blessed Husband & father. Living Life To the Fullest while living my Dream! @AdidasZA, Laureus Ambassador & Patron for FoodForward
# statuses_count: 16582
# friends_count: 830
# followers_count: 467885
# Account age (in days): 3536
# Average tweets per day: 4.69
# Most mentioned Twitter users:
# Springboks	156
# BryanHabana	141
# LaureusSport	131
# rugbyworldcup	100
# Blitzboks	63
# JohnSmit123	55
# Laureus_sa	53
# LandRoverZA	52
# HSBC_Sport	44
# WorldRugby7s	44
# Most used hashtags:
# RWC2019	64
# MotivationalMondays	28
# HSBC7s	18
# rugby	17
# TBT	15
# WebbEllisCup	12
# StartSomethingPriceless	11
# LandRover	11
# Laureus19	11
# LaureusSummit	11
# All done. Processed 3224 tweets.
# Getting data for OnigiriVal
# name: Valoo
# screen_name: OnigiriVal
# description: 27 year old animator who fangirls a lot.
# statuses_count: 67621
# friends_count: 431
# followers_count: 430
# Account age (in days): 3745
# Average tweets per day: 18.06
# Most mentioned Twitter users:
# JayDemille	106
# AndrewPatroclus	63
# J_Linebeck	62
# PhilippeHache	58
# Proton_Jon	53
# chuggaaconroy	45
# ForbiddenDusk	37
# palitra_color	36
# MasaeAnela	28
# Yobonator	27
# Most used hashtags:
# colors	36
# palette	36
# gradient	33
# palitra	33
# PokemonSwordShield	16
# TRGColo	8
# NintendoSwitch	7
# Pokemon	5
# NintendoDirect	5
# pokemon	4
# All done. Processed 3214 tweets.
# Getting data for ChrisLeeTM
# name: Chris Lee™  📱+ 🚘 = ❌
# screen_name: ChrisLeeTM
# description: EMT/Medic/Emer.Care. Support Police & All Emergency Services. Emer. 999 / Non Emer. 111/101 #999Family 🚓🚑🚒🚁 Currently Fighting S+ Reactive Arthritis 🎗
# statuses_count: 19522
# friends_count: 2071
# followers_count: 2480
# Account age (in days): 2838
# Average tweets per day: 6.88
# Most mentioned Twitter users:
# DC_ARVSgt	303
# UKCopHumour	281
# Supt_IanDS	143
# metpolsgt	141
# MrNickKnowles	121
# DC_PoliceBiker	104
# MrJWW	101
# RSSS_Assessment	91
# DC_Police	77
# K9Finn	65
# Most used hashtags:
# TeamNick	25
# ImACeleb	14
# 999Family	8
# OneTeam	5
# FF	5
# Bodmin	3
# jamfirst	3
# Apple	3
# A38	3
# PS4share	3
# All done. Processed 3199 tweets.
# Getting data for derinhwillcox
# name: Der♡
# screen_name: derinhwillcox
# description: ain't no other freak like me that's breathin 😛🤘🏼
# statuses_count: 9785
# friends_count: 755
# followers_count: 822
# Account age (in days): 1753
# Average tweets per day: 5.58
# Most mentioned Twitter users:
# bassnectar	84
# boo_wop	57
# ColorstormKid	53
# nikkiskowron	50
# pot808o	50
# thisislaith	49
# diabeyonce	37
# mandastamatakos	31
# ktlawr	25
# UnitedFlowArts	25
# Most used hashtags:
# GoGators	2
# RelentlessEffort	2
# DejaVoom	2
# NYE360	2
# BassCenterXI	2
# GatorsTogether	1
# GatorNation	1
# TheSwamp	1
# BeatAuburn	1
# BCIX	1
# All done. Processed 3120 tweets.
# Getting data for DougArmstrong
# name: Doug Armstrong 🏳️‍🌈
# screen_name: DougArmstrong
# description: globe-trotting content creator ✈️🎥🌎 gay musician 🎹 online personality 💁🏻‍♂️ #ITSOKAYTOBEGAY: https://t.co/c2AdPdSIn1
# statuses_count: 24571
# friends_count: 959
# followers_count: 103905
# Account age (in days): 4103
# Average tweets per day: 5.99
# Most mentioned Twitter users:
# SammyAlbon	135
# NikiAlbon	118
# DougArmstrong	106
# CalumMcSwiggan	98
# lindablacker	97
# nikinsammy	68
# MyNamesChai	67
# danielwebster92	59
# PlaylistLive	44
# VirginHolidays	38
# Most used hashtags:
# ad	16
# TheGreatestShowman	14
# StandUpwithYT	13
# R1TeenAwards	10
# TwitterWeekender	10
# MakeMyDay	10
# DataFreeTwitter	7
# playlistlive	6
# pride	5
# ItsOkayToBeGay	5
# All done. Processed 3194 tweets.
# Getting data for ErikaHarlacher
# name: Erika Harlacher
# screen_name: ErikaHarlacher
# description: I act & stuff~ Persona 5|Sailor Moon|Violet Evergarden|7 Deadly Sins|Yo-kai Watch|HunterxHunter|Danganronpa|Fate|Kakegurui|KH3|Toradora|Shopkins|etc etc
# statuses_count: 43599
# friends_count: 436
# followers_count: 47709
# Account age (in days): 2680
# Average tweets per day: 16.27
# Most mentioned Twitter users:
# ErikaHarlacher	92
# MaureenAPrice	47
# XanderMobusVO	45
# reagankathryn_	40
# ericalindbeck	40
# _TrueTail_	39
# churroz	38
# yugiohtas	38
# DawnMBennettVA	30
# Rachellular	30
# Most used hashtags:
# Persona5	30
# aithesomniumfiles	16
# persona5	10
# AnnTakamaki	7
# TwintailThursday	7
# KingdomHearts	5
# inktober	5
# aitsf	4
# DuckTales	4
# AITHESOMNIUMFILES	4
# All done. Processed 3226 tweets.
# Getting data for rightnowlouis
# name: t 🍉 L♥VE ON TOUR
# screen_name: rightnowlouis
# description: I just think Stevie Nicks is really fucking cool. We have met, and I was right. She's really fucking cool.
# statuses_count: 51541
# friends_count: 613
# followers_count: 728
# Account age (in days): 3035
# Average tweets per day: 16.98
# Most mentioned Twitter users:
# Louis_Tomlinson	291
# LouisPromoSquad	128
# NiallOfficial	117
# Harry_Styles	61
# bpicslouist91	39
# donnyaccent	27
# ttomlinsondaily	26
# STATSAWARDS	24
# KingLWTPromo	23
# iHeartRadio	23
# Most used hashtags:
# iHeartAwards	348
# BestSoloBreakout	305
# LouisTomlinson	305
# SlowHands	42
# BestLyrics	39
# LM5	14
# NiallHoran	8
# TwoOfUs	4
# AMAs	4
# BBMAsTopSocial	3
# All done. Processed 3137 tweets.
# Getting data for abidavisf
# name: Abi Davis-Fletcher
# screen_name: abidavisf
# description: Film Studies graduate. Taylor Swift idoliser. 🦋 Business Analyst.
# statuses_count: 18095
# friends_count: 1527
# followers_count: 560
# Account age (in days): 3894
# Average tweets per day: 4.65
# Most mentioned Twitter users:
# rhiabrey	177
# lex_birch	140
# jackdf92	134
# mellsibeth	51
# taylorswift13	49
# thevoiceuk	41
# mikefoster87	35
# MattGrimstead	32
# KelseaBallerini	30
# AbiSlocs	26
# Most used hashtags:
# TheVoiceUK	50
# LoveIsland	43
# loveisland	10
# GameofThrones	9
# GameOfThrones	8
# reputation	8
# antandox	7
# repTourNetflix	5
# LoveIsIand	5
# GBBO	3
# All done. Processed 3097 tweets.
# Getting data for Lauryn_Houseman
# name: Lou 🌸
# screen_name: Lauryn_Houseman
# description: Livin’ life to the fullest while being a doggy mommy and Auntie 🐶❣️
# statuses_count: 21703
# friends_count: 731
# followers_count: 1539
# Account age (in days): 3281
# Average tweets per day: 6.61
# Most mentioned Twitter users:
# Megan_Steele_	98
# JakePerkins__	65
# Lauryn_Houseman	56
# HaleyJorden_	39
# alyssa_lewis20	33
# annebowers_	24
# KeiziyaPate	22
# alexisbowles1	21
# AllyDestoutt	21
# brittcaupp	17
# Most used hashtags:
# NewProfilePic	10
# GreysAnatomy	6
# TheBachelorette	5
# TheBachelor	3
# thebachelorette	2
# thebachelor	2
# GBvsDAL	1
# DALvsWAS	1
# VMAs	1
# DaveChappelle	1
# All done. Processed 2764 tweets.
# Getting data for trainershanna
# name: Shanna Layne
# screen_name: trainershanna
# description: Mom, Health Coach, Pruvit Promoter, Sucker for a furry face, Ketoish, #fitboss ❤️https://t.co/MGTY35GPC5
# statuses_count: 5263
# friends_count: 106
# followers_count: 126
# Account age (in days): 3872
# Average tweets per day: 1.36
# Most mentioned Twitter users:
# TawnyVail	124
# JoelOsteen	114
# CUTEST_ANlMALS	60
# christianstt1	52
# YouTube	39
# RockLuxe	28
# fearlessmotivat	26
# marcuslemonis	25
# melrobbins	20
# GoalsOnTrack	19
# Most used hashtags:
# RockLuxe	24
# Diamonds	8
# fitness	6
# HR4HR	5
# TheProfit	5
# fitspiration	4
# todaysword	4
# LakewoodChurch	3
# fuelbetter	3
# ketones	3
# All done. Processed 1557 tweets.
# Getting data for BarackObama
# name: Barack Obama
# screen_name: BarackObama
# description: Dad, husband, President, citizen.
# statuses_count: 15689
# friends_count: 610780
# followers_count: 110384398
# Account age (in days): 4645
# Average tweets per day: 3.38
# Most mentioned Twitter users:
# WhiteHouse	190
# OFA	134
# POTUS	103
# VP	35
# ObamaFoundation	30
# MichelleObama	21
# FLOTUS	21
# BarackObama	15
# FactsOnClimate	10
# Pontifex	7
# Most used hashtags:
# ActOnClimate	273
# DoYourJob	150
# SOTU	125
# GetCovered	119
# Obamacare	78
# ImmigrationAction	70
# IranDeal	59
# SCOTUS	46
# LeadOnTrade	37
# LeadOnLeave	29
# All done. Processed 3209 tweets.
# Getting data for pigskinpug
# name: Reggie R.I.P.☘️☘️🦃
# screen_name: pigskinpug
# description: Portly, progressive, middle aged pug with a flair for caps and bow ties. Peacefully coexisting with my catbro Adrian and 2 catsis that hate me.
# statuses_count: 8999
# friends_count: 1847
# followers_count: 3616
# Account age (in days): 2865
# Average tweets per day: 3.14
# Most mentioned Twitter users:
# MisterPemberto1	307
# MomGuppy	267
# Lil_Fen	161
# indiana_pug	141
# mprinvale	138
# kath_gunn	115
# bearsbeetsbutts	110
# HamiltonPug	90
# PawhouseOz	90
# 3JazzCats	83
# Most used hashtags:
# pugchat	92
# bookiecapclub	31
# PugChat	25
# TongueOutTuesday	4
# BookieCapClub	3
# VisibleWomen	3
# NationalTellAJokeDay	3
# NationalPugDay	2
# caturday	2
# CatsOfTwitter	2
# All done. Processed 3238 tweets.
# Getting data for marwilliamson
# name: Marianne Williamson
# screen_name: marwilliamson
# description: Author, activist, non-denominational faith leader, founder of @TheWilliamsonI1. 2020 candidate for President of the United States. #marianne2020
# statuses_count: 17280
# friends_count: 390
# followers_count: 2765153
# Account age (in days): 3926
# Average tweets per day: 4.40
# Most mentioned Twitter users:
# marwilliamson	31
# shaunking	20
# tonetalks	19
# TulsiGabbard	17
# AndrewYang	16
# CNN	16
# KamalaHarris	15
# Frances_Fisher	14
# briebriejoy	13
# BernieSanders	12
# Most used hashtags:
# BigTruth	20
# bigtruth	16
# Marianne2020	15
# marianne2020	14
# DemDebate	11
# ClimateForum2020	3
# demdebate	3
# marianneforamerica	3
# Reparations	2
# Pride	2
# All done. Processed 3215 tweets.
# Getting data for neiltyson
# name: Neil deGrasse Tyson
# screen_name: neiltyson
# description: Astrophysicist
# statuses_count: 6295
# friends_count: 39
# followers_count: 13542135
# Account age (in days): 3949
# Average tweets per day: 1.59
# Most mentioned Twitter users:
# StarTalkRadio	202
# iTunesPodcasts	46
# chucknicecomic	35
# iTunes	35
# NASA	25
# JohnAllenPaulos	22
# ApplePodcasts	21
# Comic_Con	19
# starwars	19
# FOXTV	16
# Most used hashtags:
# WhenIWasYourAge	62
# Cosmos	27
# ExpressionsOfImmaturity	25
# Interstellar	24
# IKnewIWasOld	22
# WatchingCosmos	22
# FF	20
# TheForceAwakens	17
# NamesForBeyonceTwins	15
# PlutoFacts	15
# All done. Processed 3238 tweets.
# Getting data for BillNye
# name: Bill Nye
# screen_name: BillNye
# description: Science Rules! Podcast Out Now 🧪
# statuses_count: 2319
# friends_count: 124
# followers_count: 5952640
# Account age (in days): 3855
# Average tweets per day: 0.60
# Most mentioned Twitter users:
# BillNye	186
# exploreplanets	132
# thescienceguy	68
# neiltyson	49
# MichaelEMann	37
# billnyefilm	33
# DancingABC	25
# StarTalkRadio	23
# WhiteHouse	19
# netflix	18
# Most used hashtags:
# strictlyscience	31
# LightSail	21
# DWTS	19
# climatechange	14
# OceanChat	14
# HotKnowledge	12
# ActOnClimate	11
# LightSail2	9
# WHScienceFair	9
# science	8
# All done. Processed 2314 tweets.
# Getting data for eunhae_sjbabies
# name: ♡ 아니 ♡
# screen_name: eunhae_sjbabies
# description: ♡ 슈퍼주니어 ♡ 이혁재 ♡ @Supertvsubs ♡ [semi-hiatus]
# statuses_count: 226373
# friends_count: 42
# followers_count: 8913
# Account age (in days): 2117
# Average tweets per day: 106.93
# Most mentioned Twitter users:
# SJofficial	291
# Hyukkiss	188
# Haeklips	152
# F5reverEunHae	137
# EunHaeOnly	128
# smiling_hyukjae	108
# ohmaikyu	92
# AllRiseSilver	76
# incorrecteunhae	66
# dieyanakhj	53
# Most used hashtags:
# 슈퍼주니어	164
# SUPERJUNIOR	136
# SS7S	117
# SuperJuniorDnE	109
# 은혁	102
# SuperJunior	98
# 슈퍼주니어DnE	81
# 동해	80
# 땡겨	75
# Eunhyuk	60
# All done. Processed 3192 tweets.
# Getting data for EvaLongoria
# name: Eva Longoria Baston
# screen_name: EvaLongoria
# description: Actress, Producer, Director, Activist, Philanthropist, Designer, Mom, Wife, Daughter, Sister, Aunt, Friend, Stepmom, HUMAN!
# statuses_count: 16618
# friends_count: 802
# followers_count: 7217035
# Account age (in days): 3580
# Average tweets per day: 4.64
# Most mentioned Twitter users:
# EvaLongoria	554
# TheLimited	72
# GrandHotelABC	65
# shopevalongoria	49
# kenpaves	39
# lifetimetv	36
# DeviousMaids	30
# ricky_martin	24
# GlobalGiftGala	24
# OverboardMovie	21
# Most used hashtags:
# Telenovela	377
# GrandHotel	268
# TelenovelaSeason2	245
# DeviousMaids	59
# EvaForTheLimited	38
# Evamoji	30
# AskEva	27
# grandhotel	26
# EvaLongoriaCollection	21
# JaneTheVirgin	18
# All done. Processed 3172 tweets.
# Getting data for shafenoni
# name: Tuzkie babe
# screen_name: shafenoni
# description: My opinion,
# Islam my religion
# statuses_count: 9213
# friends_count: 80
# followers_count: 357
# Account age (in days): 3175
# Average tweets per day: 2.90
# Most mentioned Twitter users:
# BBNaija	30
# toluogunlesi	29
# ayosogunro	20
# Omojuwa	14
# cr8tiv_spaces	12
# MBuhari	12
# jeffphilips1	11
# HotShot57275043	11
# ogundamisi	10
# Symply_Tacha	10
# Most used hashtags:
# bbnaija	1202
# BBNaija	237
# Amajoche	178
# AMAjoche	117
# amajoche	79
# amunbroken	40
# AmAjocheFinale	34
# Amunbroken	21
# BBnaija	19
# BBNajia	18
# All done. Processed 3198 tweets.
# Getting data for maddyb_10
# name: Mad ☼
# screen_name: maddyb_10
# description:
# statuses_count: 7498
# friends_count: 743
# followers_count: 1181
# Account age (in days): 1856
# Average tweets per day: 4.04
# Most mentioned Twitter users:
# KylaCampanella	131
# MaeveeCoffey	103
# maddyb_10	90
# abbbykoeth	82
# KaityAlbone	51
# xoxokimberlyann	49
# TheRichardGibs	45
# bayboyle	44
# ZurilHendrick	44
# DJJovanFlow	43
# Most used hashtags:
# NewProfilePic	11
# BillsMafia	2
# blessed	2
# GoBoro	2
# rip	2
# librarythoughts	1
# letsgetspooky	1
# fabfive	1
# happyearthday	1
# TheBachelor	1
# All done. Processed 2970 tweets.
# Getting data for RachelBLevinson
# name: Rachel Levinson-Waldman
# screen_name: RachelBLevinson
# description: Senior Counsel, Liberty & National Security Program, @BrennanCenter (DC). Native Austinite. Views are my own.
# statuses_count: 16893
# friends_count: 1271
# followers_count: 4557
# Account age (in days): 2725
# Average tweets per day: 6.20
# Most mentioned Twitter users:
# BrennanCenter	187
# FaizaPatelBCJ	106
# cylev	65
# LizaGoitein	63
# RachelBLevinson	53
# alvarombedoya	41
# ArielTzedekDC	39
# AngelSDiaz_	38
# AmesCG	36
# TzedekDC	34
# Most used hashtags:
# SOTU	12
# MuslimBan	10
# CVE	8
# ColorofSurveillance	7
# BCJlive	7
# NoMuslimBanEver	6
# emergencypowers	5
# FamiliesBelongTogether	5
# ColorOfSurveillance	5
# Zuckerberg	5
# All done. Processed 3212 tweets.
# Getting data for CarryMinati
# name: Ajey Nagar
# screen_name: CarryMinati
# description: Ye apna Official hai.
# statuses_count: 7673
# friends_count: 59
# followers_count: 863466
# Account age (in days): 1847
# Average tweets per day: 4.15
# Most mentioned Twitter users:
# CarryMinati	219
# ashchanchlani	41
# Bhuvan_Bam	30
# YouTubeIndia	28
# the_amo_secret	25
# emNikhil	24
# OneDigitalEnt	21
# ZoufaKhan	13
# CM_GAURAV	13
# thetanmay	13
# Most used hashtags:
# DominatetheGame	5
# AyeCarry	4
# HPIndia	4
# ayecarry	3
# chutiyaquadplay	3
# DominateTheGame	3
# YTNextUp	2
# modernlove	2
# ytff	2
# nolight	1
# All done. Processed 3196 tweets.
# Getting data for ethanesquick
# name: 𝕜𝕒𝕥𝕚𝕖★//ALLY MONTH
# screen_name: ethanesquick
# description: my only achievement in life was that one time i picked up ethan
# statuses_count: 36006
# friends_count: 474
# followers_count: 1154
# Account age (in days): 1054
# Average tweets per day: 34.16
# Most mentioned Twitter users:
# pIutotic	498
# CrankGameplays	361
# briskwolf	271
# sirenmika	225
# iceddarkroasts	185
# allyienjerky	115
# eggynestor	99
# fantasticswm	98
# cuckiplier	91
# ethanesquick	85
# Most used hashtags:
# crankgameplaysvidcon19	8
# VidConUS	4
# heapassgives	2
# ahwm	1
# AHWM	1
# AppleEvent	1
# 7yearsofcgp	1
# NationalDogDay	1
# dentistsforcontent	1
# KeepOnChuggin	1
# All done. Processed 3195 tweets.
# Getting data for mlota_azola
# name: Azola Mlota
# screen_name: mlota_azola
# description: Events  - PR & Promotions.  #UmjoloWithAzola - Weekends
# Email: am@azolamlota.co.za
# statuses_count: 163193
# friends_count: 12209
# followers_count: 134522
# Account age (in days): 2150
# Average tweets per day: 75.90
# Most mentioned Twitter users:
# mlota_azola	885
# UmjoloWithAzola	42
# KFCSA	23
# BeynonSammy	12
# Reeyaness	10
# sindivanzyl	10
# GPSportAwards	10
# MbaliHlopheSA	10
# Siphe_Zizi	8
# PhindileMsokwi1	8
# Most used hashtags:
# Umjolowithazola	438
# uMjoloWithAzola	410
# KFCProposal	56
# umjolowithazola	50
# SingleFlames	23
# UmjoloWithAzola	10
# UmjolowithAzola	9
# umjolowithAzola	6
# UMjoloWithAzola	6
# KFCWEDDING	5
# All done. Processed 3184 tweets.
# Getting data for AceNcobo
# name: Ace Ncobo - Spot On
# screen_name: AceNcobo
# description: I am nothing but an ordinary rural boy involved in doing extraordinary things for others
# statuses_count: 8102
# friends_count: 730
# followers_count: 15004
# Account age (in days): 2671
# Average tweets per day: 3.03
# Most mentioned Twitter users:
# AceNcobo	835
# SAFA_net	342
# nealcol	124
# robertmarawa	120
# DChimhavi	93
# BafanaBafana	38
# KickOffMagazine	33
# SimplyCarol8	29
# FIFAcom	27
# Tildy992	26
# Most used hashtags:
# diskisimplified	6
# KFCProposal	6
# ExtraTime	6
# SAFA	5
# MSW	4
# SSDiski	4
# ssdiski	3
# SAfmSoundAwake	3
# CountryDuty	3
# KFCWEDDING	2
# All done. Processed 3150 tweets.
# Getting data for WeLuvAllyB
# name: Mama and Papa H💋
# screen_name: WeLuvAllyB
# description: Blessed to be Proud Parents of Brandon & Ally Brooke Hernandez. We support & praise God for the lovely & talented group Fifth Harmony! Luv u girls! 3.
# statuses_count: 23047
# friends_count: 1961
# followers_count: 155696
# Account age (in days): 2467
# Average tweets per day: 9.34
# Most mentioned Twitter users:
# AllyBrooke	1369
# AllyBrookeOn	441
# ArtistHBTL	260
# SashaFarber	161
# DancingABC	157
# vocallyist	134
# PromotingAlly	124
# AllyOnDWTS	74
# coconilaa	74
# allybrasilcom	72
# Most used hashtags:
# LipsDontLie	327
# DWTS	320
# TeamTime2Shine	99
# Higher	60
# AllyOnDWTS	33
# Allygiance	26
# AllyBrooke	25
# StreamHigher	20
# ShazamLipsDontLie	20
# TeamTimeToShine	14
# All done. Processed 3202 tweets.
# Getting data for Juliannadago
# name: Ju 🌼
# screen_name: Juliannadago
# description: adrian wsocc ‘22 l luke 6:31 | GOOD VIBES 🤙🏽
# statuses_count: 3594
# friends_count: 669
# followers_count: 688
# Account age (in days): 1580
# Average tweets per day: 2.27
# Most mentioned Twitter users:
# soccersab13	47
# ellie_laporte	43
# KohnJenna	32
# kassidy_miller2	31
# MonicaDostert	27
# OPotestato	27
# Juliannadago	27
# LCNGirlsSoccer	22
# AdrianWSoccer	18
# haileysirut	18
# Most used hashtags:
# TheDZone	6
# SSS	4
# WAR	4
# NewProfilePic	3
# TheBachelor	3
# D3MIAA	2
# ONTHECLOCK	2
# LGRW	2
# REDWINGS	2
# GoBlue	2
# All done. Processed 3004 tweets.
# Getting data for 2Saintt
# name: 2saint
# screen_name: 2Saintt
# description: Age 21. SSBM World Rank #44. Student. Streamer. Professional Gamer. Free Agent.
# statuses_count: 6112
# friends_count: 260
# followers_count: 7866
# Account age (in days): 1927
# Average tweets per day: 3.17
# Most mentioned Twitter users:
# 2Saintt	187
# iBDWSSBM	184
# TSM_Leffen	87
# LiquidHbox	71
# pg_zain	50
# MatthewPTrotta	50
# rishissb	49
# FictionIRL	45
# DarktoothVG	43
# HugS86	42
# Most used hashtags:
# ClearMentality	20
# MnTFam	11
# SmashSummit	9
# CEO2018	6
# MnTFGC	5
# DHATL18	4
# Shine2018	4
# SSC18	4
# G6	3
# Giveaway	3
# All done. Processed 3180 tweets.
# Getting data for katyperry
# name: KATY PERRY
# screen_name: katyperry
# description: Love. Light.
# statuses_count: 10149
# friends_count: 221
# followers_count: 108290198
# Account age (in days): 3927
# Average tweets per day: 2.58
# Most mentioned Twitter users:
# katyperry	121
# kpcollections	62
# AmericanIdol	60
# LukeBryanOnline	55
# LionelRichie	37
# cynthialovely	26
# HillaryClinton	25
# RyanSeacrest	23
# ABCNetwork	21
# YouTube	20
# Most used hashtags:
# americanidol	240
# AmericanIdol	214
# KPWWW	71
# WITNESSTHETOUR	57
# WITNESS	39
# NeverReallyOver	26
# ChainedToTheRhythm	25
# HarleysInHawaii	21
# RISE	19
# CHAINEDTOTHERHYTHM	18
# All done. Processed 3192 tweets.
# Getting data for XUKUNlSM
# name: cai xukun supremacist ♡
# screen_name: XUKUNlSM
# description: [ CLOSED ] 180512
# statuses_count: 6230
# friends_count: 39
# followers_count: 2850
# Account age (in days): 712
# Average tweets per day: 8.75
# Most mentioned Twitter users:
# wenjunloveclub	126
# yanjunies	122
# caerium	101
# zhengrbins	67
# ZHENGTlNGS	59
# yanchened	54
# XUKUNlSM	39
# iammcjin	37
# zhengchens	37
# idol2018_qiyi	33
# Most used hashtags:
# 蔡徐坤	214
# 偶像练习生	160
# IdolProducer	111
# 百分九少年	101
# NinePercent	94
# CaiXukun	16
# 차이쉬쿤	16
# caixukun	12
# IdolProducerFinals	11
# idolproducer	9
# All done. Processed 3160 tweets.
# Getting data for emNikhil
# name: Nikhil Sharma
# screen_name: emNikhil
# description: Vlogger , Youtuber, Actor !
# statuses_count: 4273
# friends_count: 62
# followers_count: 236841
# Account age (in days): 3440
# Average tweets per day: 1.24
# Most mentioned Twitter users:
# YouTube	479
# emNikhil	106
# raghavdubey1234	84
# Shanice3195	50
# YouTubeIndia	50
# ASUSIndia	48
# CarryMinati	32
# Sarthak0207	32
# TechnicalGuruji	26
# weirdoyt	24
# Most used hashtags:
# CreatorSummit	7
# YTFF	6
# AskMN	6
# TrueWanderer	4
# Live2Wander	4
# MumbikerNikhil	3
# NexaLifestyle	3
# YTFF2019	2
# mnsquad	2
# LFW	2
# All done. Processed 3210 tweets.
# Getting data for Miss_Arilicious
# name: ✨𝓐𝓻𝓲🌙
# screen_name: Miss_Arilicious
# description: Freelance Illustrator ✨ 💬EN/ESP COMMISSIONS:CLOSED, Pm for info! 🌐Instagram: MissArilicious
# statuses_count: 10023
# friends_count: 563
# followers_count: 4745
# Account age (in days): 1986
# Average tweets per day: 5.05
# Most mentioned Twitter users:
# __shslprince	225
# 1aughingstock	183
# c01a_	159
# TruAuraGuardian	72
# BLNdraws	71
# le_nouv_eau	65
# qosicart	58
# 1auriam	57
# signelchan	54
# donutous	51
# Most used hashtags:
# momoharuweek2019	9
# キスの日	4
# ndrv3	3
# danganronpa	2
# ダンガンロンパ	2
# E3	2
# 東条斬美生誕祭2019	2
# digimon	2
# art	1
# スーパーダンガンロンパ2	1
# All done. Processed 3247 tweets.
# Getting data for ashchanchlani
# name: Ashish Chanchlani
# screen_name: ashchanchlani
# description: Youtuber..Actor...wo vines wala guy • https://t.co/M7viPMdRvJ • https://t.co/5QRqFd806z
# statuses_count: 3379
# friends_count: 304
# followers_count: 604704
# Account age (in days): 3593
# Average tweets per day: 0.94
# Most mentioned Twitter users:
# ashchanchlani	451
# Medicofreakria	146
# kanakhilnani	97
# YouTubeIndia	55
# damrupani	50
# CarryMinati	47
# Bhuvan_Bam	43
# akshaykumar	36
# YTCreatorsIndia	30
# Marvel_India	27
# Most used hashtags:
# AvengersEndgame	8
# YTFF	8
# BhaiYetohShuruHoteHiKhatamHoGaya	8
# InfinityWar	7
# MIBInternational	6
# HappyDiwali	5
# AshishChanchlani	5
# War	5
# fan	5
# ashishchanchlani	4
# All done. Processed 3206 tweets.
# Getting data for LoganPaul
# name: Logan Paul
# screen_name: LoganPaul
# description: Goofy dude with BIG goals. Instagram: LoganPaul
# statuses_count: 8856
# friends_count: 4601
# followers_count: 5168714
# Account age (in days): 2933
# Average tweets per day: 3.02
# Most mentioned Twitter users:
# LoganPaul	84
# jakepaul	66
# ElJuanpaZurita	38
# Dwarf_Mamba	36
# KSIOlajidebt	33
# YouTube	24
# whydontwemusic	23
# mikemajlak	21
# GeorgeJanko	19
# MaverickParrot	18
# Most used hashtags:
# AirplaneModeMovie	29
# LoganPaulVS	16
# TheThinning	15
# BeAMaverick	14
# RiseOfThePauls	8
# AskSpaceBetween	8
# Logang4Life	7
# ad	7
# TheChallengerGames	6
# TeenChoice	6
# All done. Processed 3217 tweets.
# Getting data for TheTeawrex
# name: Sam (Teawrex)
# screen_name: TheTeawrex
# description: Partnered Broadcaster at Twitch // A Charity Guy for @gcxevent // Profile by: @AR_McD // Header by @DrAssenov // For business: teawrex@opg.tv
# statuses_count: 22127
# friends_count: 535
# followers_count: 72112
# Account age (in days): 3551
# Average tweets per day: 6.23
# Most mentioned Twitter users:
# Bungie	77
# Gothalion	70
# Professorbroman	69
# A_dmg04	66
# TheTeawrex	57
# CharOnTwitch	52
# PaulTassi	37
# Skirtzzz	36
# rawrsnacks	34
# AustenMarieTV	33
# Most used hashtags:
# MTNDEWAMPGAMEFUEL	5
# gameofthrones	5
# ad	3
# Iceborne	3
# sponsored	3
# D2Game2Give	2
# TI9	2
# E32019	2
# MOTW	2
# got	2
# All done. Processed 3233 tweets.
# Getting data for loveonlycr
# name: -Di
# screen_name: loveonlycr
# description: less hate and more love. || fan account.
# statuses_count: 26500
# friends_count: 500
# followers_count: 3326
# Account age (in days): 1017
# Average tweets per day: 26.06
# Most mentioned Twitter users:
# calleypocheoffi	469
# vaniaxcyp	312
# Pochosaurus	221
# danielaacallee	189
# renattaxcache	84
# karlaalsr	84
# Cachedreaming	84
# raygal_cb	73
# lauritaSkereeeT	71
# ClauStefan1	69
# Most used hashtags:
# Felices24Poché	3
# 22Nov	2
# ParoNacional	2
# RomanceIsComing	2
# 7MillonesDeCachers	2
# PiñeraRenuncia	2
# ToqueDeQueda	1
# CacerolazoPorColombia	1
# ElParoSigue	1
# Cacerolazo22N	1
# All done. Processed 3196 tweets.
# Getting data for GerberKawasaki
# name: Ross Gerber
# screen_name: GerberKawasaki
# description: Co-Founder & #CEO, #InvestmentAdvisor. #Stock market #investor #musician #Fintech innovator app: https://t.co/FpDEbFc6bf  Disclaimer - https://t.co/yTYGH9zoht
# statuses_count: 66904
# friends_count: 4915
# followers_count: 61675
# Account age (in days): 3031
# Average tweets per day: 22.07
# Most mentioned Twitter users:
# elonmusk	159
# GerberKawasaki	61
# Tesla	58
# hatemdhiab	52
# vincent13031925	48
# Gfilche	45
# BsiflingTrades	41
# TDANetwork	40
# miantosca4	39
# nytimes	30
# Most used hashtags:
# tesla	46
# Tesla	36
# DisneyPlus	36
# ClimateChange	27
# cannabis	22
# Cybertruck	13
# ClimateCrisis	13
# disney	13
# gaming	12
# WeWork	12
# All done. Processed 3203 tweets.
# Getting data for aprilwensel
# name: April Wensel
# screen_name: aprilwensel
# description: Founder of Compassionate Coding (@compassioncode) | Engineering Leader | Keynote Speaker | Ultra Runner | Ethical Vegan
# statuses_count: 28568
# friends_count: 7473
# followers_count: 27372
# Account age (in days): 3406
# Average tweets per day: 8.39
# Most mentioned Twitter users:
# aprilwensel	361
# compassioncode	210
# ImpactSummit_	29
# AndyHaskell2013	28
# Microsoft	27
# Brisa	17
# ncraftsConf	17
# aline_mokfa	16
# MaritvanDijk77	16
# JessicaMauerhan	14
# Most used hashtags:
# PlantPower	54
# WhatVegansEat	21
# NewCrafts	17
# CCEuroTour	14
# CompassionateCoding	13
# newcrafts	11
# ImpactSummit19	9
# coding	5
# tech	5
# vegan	4
# All done. Processed 3212 tweets.
# Getting data for Smatterbrain
# name: Kieran #SobbleSquad
# screen_name: Smatterbrain
# description: I’m a highly food-motivated digital artist with a passion for zoology, anatomy, horror films, taxidermy, and animal education. Contact me: Smatterbugs@gmail.com
# statuses_count: 54003
# friends_count: 841
# followers_count: 7534
# Account age (in days): 1399
# Average tweets per day: 38.60
# Most mentioned Twitter users:
# Smatterbrain	120
# BarghestBlack	67
# Virivax	67
# DrunkenDirewolf	47
# TojoTheThief	33
# TwistHound	28
# Blackmudpuppy	27
# KingTrashPossum	27
# doevember	26
# woIffangs	24
# Most used hashtags:
# TeamFish	3
# NationalComingOutDay	3
# StraightPrideParade	3
# babyvulture	2
# zbrush	2
# pokemonleaks	2
# swshspoilers	2
# teeth	2
# pokemonleak	2
# NewProfilePic	2
# All done. Processed 3216 tweets.
# Getting data for AtomicRy
# name: Ryleigh
# screen_name: AtomicRy
# description: Illustrator/concept artist/bassist. Email: theatomicry@gmail.com Buy me a beer🍺: https://t.co/ga650XJ0qz
# statuses_count: 18164
# friends_count: 725
# followers_count: 1651
# Account age (in days): 1915
# Average tweets per day: 9.49
# Most mentioned Twitter users:
# deathdrive420	277
# Pois0nJam	153
# CallegosY	118
# BlkDistraction	49
# ModestCube	41
# kennsyn	34
# maltairs	33
# Moshminki	32
# AtomicRy	31
# Liz_Caingcoy	25
# Most used hashtags:
# inktober	8
# StrangerThings	5
# illustration	4
# NetNeutrality	4
# digitalart	3
# BlackPanther	3
# ThePunisher	3
# TheEvilDead	2
# ghostface	2
# MeetTheArtist	2
# All done. Processed 2575 tweets.
# Getting data for jackieepelayo
# name: jack-o
# screen_name: jackieepelayo
# description:
# statuses_count: 39009
# friends_count: 792
# followers_count: 2053
# Account age (in days): 1766
# Average tweets per day: 22.09
# Most mentioned Twitter users:
# maureena002	85
# zepolilsel	45
# jackieepelayo	26
# Armandoc_53	21
# lisdoloress	19
# jjoelworld	18
# ok_meraa	18
# PrataNicholas	16
# itsscinndy_	14
# Esmerisa11	12
# Most used hashtags:
# FIFAWWC	8
# NewProfilePic	7
# OneNationOneTeam	3
# MetGala	3
# USWNT	2
# USA	2
# USANED	2
# metgala	2
# METGala	2
# 18YearsPhilosophersStoneFilm	1
# All done. Processed 3023 tweets.
# Getting data for antoinetterrrz
# name: antoinette🍓
# screen_name: antoinetterrrz
# description: why you built like that
# statuses_count: 14734
# friends_count: 650
# followers_count: 699
# Account age (in days): 1880
# Average tweets per day: 7.84
# Most mentioned Twitter users:
# Dodgers	56
# KianAndJc	39
# Stranger_Things	39
# shanedawson	33
# JeffreeStar	28
# groovyvvic	23
# _Toruno	22
# antoinetterrrz	19
# codyko	19
# RickandMorty	19
# Most used hashtags:
# StrangerThings	14
# Dodgers	13
# D23Expo	11
# DodgersWin	10
# ShanexJeffree	9
# RickandMorty	7
# ITFDB	6
# therealityhouse	4
# DisneyPlus	3
# NewProfilePic	3
# All done. Processed 2938 tweets.
# Getting data for EstherThePig
# name: Esther TheWonder Pig
# screen_name: EstherThePig
# description: “The True Adventures of Esther the Wonder Pig” ,the greatest children’s book of all time (according to my Grandma) is available now in stores, and online.
# statuses_count: 43093
# friends_count: 2291
# followers_count: 71015
# Account age (in days): 2165
# Average tweets per day: 19.90
# Most mentioned Twitter users:
# EstherThePig	189
# GretaThunberg	156
# WBrettWilson	153
# esthers_kitchen	72
# kirstiealley	60
# HEEFS_	52
# CTVNews	50
# CBCNews	47
# JaneFallon	39
# JustinTrudeau	37
# Most used hashtags:
# ThrowbackThursday	30
# BeKindToAllKinds	23
# KindnessIsMagic	13
# plantbased	4
# SweetDreamsMyFriends	4
# throwbackthursday	3
# LoveIsLove	3
# EstherApproved	3
# estherapproved	3
# nailedit	3
# All done. Processed 3234 tweets.
# Getting data for jessiepaege
# name: Jessie Paege
# screen_name: jessiepaege
# description: ⭐️ youtuber ⭐️ hufflepuff 🏳️‍🌈 bleaching my hair is a personality trait
# statuses_count: 9480
# friends_count: 1191
# followers_count: 308786
# Account age (in days): 2155
# Average tweets per day: 4.40
# Most mentioned Twitter users:
# jessiepaege	270
# CrankThatFrank	192
# hiropaege	90
# EvaDeMuro	58
# ElloSteph	48
# AnthonyAmorim	44
# olliepaege	34
# jessieasrats	32
# gayforpaege	31
# pokemonpaege	27
# Most used hashtags:
# TikTok	6
# NationalComingOutDay	2
# WorldMentalHealthDay	2
# lovingqueers	2
# SpiritDay	1
# NotAPhase	1
# notaphase	1
# VidConNOW	1
# PrideMonth	1
# pridemonth	1
# All done. Processed 3208 tweets.
# Getting data for LeVeonBell
# name: Le'Veon Bell
# screen_name: LeVeonBell
# description: All Pro NFL Running Back • New York Jets • Business: leveonbellbiz@gmail.com
# statuses_count: 26922
# friends_count: 388
# followers_count: 1872993
# Account age (in days): 3408
# Average tweets per day: 7.90
# Most mentioned Twitter users:
# LeVeonBell	66
# steelers	46
# NFL	29
# drinelli	20
# ImVarTho	12
# nyjets	11
# TeamJuJu	10
# TheAdamsEra	9
# nflnetwork	8
# HotNewHipHop	8
# Most used hashtags:
# Juice	48
# Steelers	27
# PostInterview	18
# juice	14
# 17Weeks	10
# TakeFlight	8
# SteelerNation	7
# 26Savage	7
# ShrimpBayless	7
# JuiceIsLoose	7
# All done. Processed 3086 tweets.
# Getting data for Casey
# name: Casey Neistat
# screen_name: Casey
# description: family + work
# statuses_count: 24037
# friends_count: 2131
# followers_count: 2043532
# Account age (in days): 3453
# Average tweets per day: 6.96
# Most mentioned Twitter users:
# 368	84
# mcwm	65
# MKBHD	55
# lovebillynyc	49
# Tesla	38
# Casey	37
# JonErlichman	35
# samsheffer	35
# PhillyD	29
# YouTube	27
# Most used hashtags:
# TeamTrees	3
# HotOnes	3
# NYCMarathon	3
# Bellator228	2
# GoT	2
# TheBurgerShow	2
# NYC	2
# CYBRTRK	1
# KIDZBOPDad	1
# momlife	1
# All done. Processed 3208 tweets.
# Getting data for MrBeastYT
# name: MrBeast
# screen_name: MrBeastYT
# description: Human ATM
# statuses_count: 2723
# friends_count: 1180
# followers_count: 4365028
# Account age (in days): 2042
# Average tweets per day: 1.33
# Most mentioned Twitter users:
# MrBeastYT	101
# KEEMSTAR	95
# YouTube	57
# pewdiepie	42
# LeonLush	39
# LazarBeamYT	38
# CouRageJD	33
# MarkRober	31
# TeamYouTube	30
# Ninja	24
# Most used hashtags:
# TeamTrees	27
# teamtrees	7
# ad	4
# TEAMTREES	1
# TeenChoice	1
# ChoiceMaleWebStar	1
# weready	1
# BringIt	1
# relatable	1
# LookAtMeImSoCool	1
# All done. Processed 2551 tweets.
# Getting data for AyoDaewon
# name: ѕυηѕнιηє ∂αєωση 💕
# screen_name: AyoDaewon
# description: Waipeujagi 💕 ꜱᴜɴꜱʜɪɴᴇ ᴅᴀᴇᴡᴏɴ He deserves everyone's support.  𝓘 𝓵𝓲𝓿𝓮 𝓯𝓸𝓻 ∂αєωση's 𝓢𝓜𝓘𝓛𝓔. To the people who loves him, I love you all too.
# statuses_count: 8476
# friends_count: 137
# followers_count: 305
# Account age (in days): 697
# Average tweets per day: 12.16
# Most mentioned Twitter users:
# official_UN_B	276
# Primavera_92	143
# khalbuff	120
# Wonderfuldaewon	71
# wop_317	64
# newspring_dw	45
# 317daewon	45
# tinkboy920317	44
# iam_ehmgee	38
# thankyou92s	38
# Most used hashtags:
# 대원	1008
# UNB	985
# 유앤비	943
# DAEWON	660
# 박대원	516
# デウォン	199
# Daewon	136
# MADTOWN	121
# 매드타운	117
# BLACKHEART	98
# All done. Processed 3102 tweets.
# Getting data for alexarodrigguez
# name: a ℓ e x a🦋
# screen_name: alexarodrigguez
# description: 👻 alexamarie_1998
# statuses_count: 12159
# friends_count: 956
# followers_count: 24676
# Account age (in days): 3043
# Average tweets per day: 4.00
# Most mentioned Twitter users:
# alexarodrigguez	258
# AlyciaTyre	71
# daisymarquez_	53
# amrezy	47
# NikitaDragun	37
# offlinemalek	30
# gayanaxo	28
# tinahalada	24
# marie_brownsuga	22
# brigarzza	19
# Most used hashtags:
# NewProfilePic	5
# Libras	5
# GoSpursGo	5
# SuperCashAppFriday	3
# laurasboutique	3
# WIN	3
# NYFW	2
# Emmys	1
# emmys	1
# 21stbirthday	1
# All done. Processed 2978 tweets.
# Getting data for NYGiantsRush
# name: NYGiantsRush.com
# screen_name: NYGiantsRush
# description: Original NY Giants content. Podcast: “The Giants Guys” iTunes/Podbean. Former B/R NY Giants Columnist. Hustle till you no longer have to introduce yourself.
# statuses_count: 23805
# friends_count: 666
# followers_count: 4375
# Account age (in days): 2310
# Average tweets per day: 10.31
# Most mentioned Twitter users:
# NYGiantsRush	722
# nyspawtsguy_spi	170
# CraigSantucci	141
# Giants	103
# John_Fennelly	76
# MdoubleJB	73
# CarlBanksGIII	66
# COOLLANEHERO	65
# Jeff_nyg	64
# slemarie	59
# Most used hashtags:
# Giants	26
# GiantsPride	12
# NYGIANTS	9
# NYGiants	7
# giants	5
# putlovein	5
# NYG	5
# gmen	3
# XFL	3
# nyg	2
# All done. Processed 3221 tweets.
# Getting data for RareAccount
# name: skywalter ( ._.)
# screen_name: RareAccount
# description: R🖤
# statuses_count: 21229
# friends_count: 674
# followers_count: 741
# Account age (in days): 2999
# Average tweets per day: 7.08
# Most mentioned Twitter users:
# ZackOSully	86
# wookarz	68
# _phonginator	67
# rad_rachelll	65
# acaiprincess	58
# fiend_malto	34
# UndergroundEnt_	32
# itzzfaith	30
# Keekz_13	26
# iamanthasdead	22
# Most used hashtags:
# Funko	3
# Exclusive	3
# DeadlyClass	3
# TheEnd	2
# NYCC	2
# Zombieland2	2
# StarWarsJediFallenOrder	2
# DPMO	2
# daforce	1
# Larain	1
# All done. Processed 3143 tweets.
# Getting data for jakepaul
# name: Jake Paul
# screen_name: jakepaul
# description: problem child - rock collector - big capper - abstinent - house husband - paleontologist - crocodile enthusiast - part time thief - chris daughtry fan
# statuses_count: 10518
# friends_count: 9181
# followers_count: 3696951
# Account age (in days): 2747
# Average tweets per day: 3.83
# Most mentioned Twitter users:
# jakepaul	144
# dobrelucas	62
# dobremarcus	61
# LoganPaul	58
# Team10official	32
# AlissaViolet	32
# alexmlange	30
# tanamongeau	28
# erika_costell	19
# tristantales	16
# Most used hashtags:
# Bizaardvark	7
# JakeChoiceAwards	5
# YouGottaWantIt	4
# TeenChoice	4
# T10Tour	3
# TeamPaul	2
# NewProfilePic	2
# SponsoredbyEA	2
# JakePaul	2
# RDMA	2
# All done. Processed 3202 tweets.
# Getting data for christiand
# name: christian delgrosso
# screen_name: christiand
# description: SUBSCRIBE👉🏻 https://t.co/XQkFplgG52 Business Inquiries: Christiandmanagement@gmail.com
# statuses_count: 12603
# friends_count: 111860
# followers_count: 1306651
# Account age (in days): 2617
# Average tweets per day: 4.82
# Most mentioned Twitter users:
# christiand	253
# KristenMcgowann	115
# KRISTENMCG2	64
# YouTube	55
# AmandaCerny	29
# AaronCarpenter	17
# blackpills	17
# yuppjulian	14
# camerondallas	13
# jovanijara	12
# Most used hashtags:
# ad	6
# ANAMasters	4
# JustAnotherDayAtTheOffice	4
# NetNeutrality	3
# BellLetsTalk	3
# ownthemoment	3
# americanragpack	3
# HHN27	2
# sweepstakes	2
# Ad	2
# All done. Processed 3199 tweets.
# Getting data for Frogiiii
# name: Lance 💕
# screen_name: Frogiiii
# description: She/her • Comics • Overwatch/OWL • Would die for Troyce and Bruce Banner 💞
# statuses_count: 7913
# friends_count: 0
# followers_count: 223
# Account age (in days): 1141
# Average tweets per day: 6.94
# Most mentioned Twitter users:
# RawMeSombra	131
# chxvez	74
# Iakitu	66
# happyarmin	57
# Muma	30
# PlayOverwatch	30
# daddykapIan	26
# Geguri2	24
# waterfallmirage	23
# Luminos_Smudge	19
# Most used hashtags:
# overwatch	22
# OWL2018	10
# Overwatch	8
# Deadpool2	6
# voltron	4
# ShieldsUP	3
# HappyHeroDays	3
# reaper	3
# SebastianInArgCC2018	2
# InfinityWar	2
# All done. Processed 2654 tweets.
# Getting data for lelepons
# name: Lele Pons
# screen_name: lelepons
# description: CREATOR ❤️ / mgmt: teamlele@shots.com / LISTEN TO LOS PUTI👇
# statuses_count: 11246
# friends_count: 35914
# followers_count: 1924218
# Account age (in days): 2193
# Average tweets per day: 5.13
# Most mentioned Twitter users:
# lelepons	1423
# shots	307
# HannahStocking	244
# rudymancuso	169
# YouTube	131
# john	128
# ElJuanpaZurita	123
# Spotify	118
# anwar	107
# Anitta	79
# Most used hashtags:
# Dicen	45
# Celoso	45
# CELOSO	24
# TeenChoice	20
# LaVozLele	20
# LaVozMexico	17
# LelePons	16
# lelepons	14
# LatinAMAs	14
# MissUniverse	14
# All done. Processed 3178 tweets.
# Getting data for CollinsKey
# name: Collins Key
# screen_name: CollinsKey
# description: Instagram/Snapchat: @CollinsKey
# statuses_count: 14315
# friends_count: 10339
# followers_count: 317669
# Account age (in days): 2990
# Average tweets per day: 4.79
# Most mentioned Twitter users:
# CollinsKey	359
# itsdevankey	114
# veronicamerrell	33
# VanessaMerrell	28
# BrookAndBailey	19
# GloZell	18
# Bryan_L_Johnson	17
# awesomenesstv	14
# YouTube	13
# ATTHelloLab	13
# Most used hashtags:
# CollinsKeyTweetMe	29
# KeyperFamily	28
# CollinsKeyDMSpree	18
# MailBoxMonday	14
# Keypers	13
# ad	9
# KeyperOfTheWeek	9
# BusHoppers	8
# KeyBrosTweetSpree	8
# CollinsNewVideo	7
# All done. Processed 3213 tweets.
# Getting data for allmainlin
# name: 💚
# screen_name: allmainlin
# description: 그동안 고마워 😌 관린이 덕분에 정말 행복했어 💚
# statuses_count: 17393
# friends_count: 75
# followers_count: 8310
# Account age (in days): 748
# Average tweets per day: 23.25
# Most mentioned Twitter users:
# kuanlin_sns	230
# lai_kuanlin923	174
# allmainlin	150
# LAI_KUANLIN_twt	94
# cubeunited	79
# laiwinks	77
# dreamboylin	52
# vitaminforlai	45
# OFFICIAL_C9BOYZ	43
# Park_Jihoon_twt	40
# Most used hashtags:
# 라이관린	1005
# 賴冠霖	354
# LAIKUANLIN	304
# 赖冠霖	291
# 배진영	201
# 박지훈	150
# 우석X관린	102
# BAEJINYOUNG	95
# WOOSEOKXKUANLIN	58
# 별짓	51
# All done. Processed 3113 tweets.
# Getting data for Dwilliams1515
# name: David Williams
# screen_name: Dwilliams1515
# description: Coach at Peoria Manual & Former Coach of Mac Irvin Fire AAU & NJCAA BHE & CBL'S River City Panthers.Certified USA Basketball Coach.Workout Pro's and D1 players.
# statuses_count: 9793
# friends_count: 3129
# followers_count: 3012
# Account age (in days): 3230
# Average tweets per day: 3.03
# Most mentioned Twitter users:
# AceWolf44	166
# kylekuzma	104
# TheMacIrvinFire	88
# scottybscout	82
# DAWilliams14	71
# Sports_Aaron	46
# Amagylon	44
# Lakers	40
# Cubs	37
# riv_isaiah	35
# Most used hashtags:
# Illini	63
# MacIrvinFire	29
# Cubs	20
# salute	18
# EverybodyIn	16
# workoutguy	13
# EYBL	13
# pjspreps	12
# FlyTheW	12
# NBAVote	12
# All done. Processed 3165 tweets.
# Getting data for JohnLegere
# name: John Legere
# screen_name: JohnLegere
# description: Magenta-wearing, customer-loving @TMobile USA CEO focused on ending wireless pain points & scaring our competitors! Also, #IamBatman
# statuses_count: 54658
# friends_count: 295
# followers_count: 6510094
# Account age (in days): 2397
# Average tweets per day: 22.80
# Most mentioned Twitter users:
# TMobile	1058
# verizon	122
# ATT	114
# TMobileHelp	96
# JohnLegere	44
# SievertMike	42
# JonFreier	39
# NevilleRay	35
# LegereDoll	29
# MLB	22
# Most used hashtags:
# SlowCookerSunday	75
# RuffFriday	26
# LIVE	21
# TMobileTuesdays	18
# NewTMobile	15
# iPhone11	14
# uncarrier	13
# TeamMagenta	12
# TMoBell	12
# TMobileWingman	11
# All done. Processed 3210 tweets.
# Getting data for EthanDolan
# name: Ethan Dolan
# screen_name: EthanDolan
# description: I make videos with my twin brother
# statuses_count: 7111
# friends_count: 18078
# followers_count: 8120004
# Account age (in days): 2217
# Average tweets per day: 3.21
# Most mentioned Twitter users:
# GraysonDolan	112
# EthanDolan	38
# jamescharles	17
# emmachamberlain	13
# BryantEslava	12
# JeffreeStar	10
# RyanAbe	10
# innocentgrayson	4
# RickyPDillon	4
# larrayxo	4
# Most used hashtags:
# DolanTwinsNewVideo	85
# TeenChoice	7
# AskEthanAndGrayson	6
# DolansTwinNewVideo	5
# EthansHair	4
# ChoiceYouTuber	3
# ChoiceMaleWebStar	3
# DolanTwinNewVideo	2
# NewProfilePic	1
# BrothersDay	1
# All done. Processed 3208 tweets.
# Getting data for RomanAtwood
# name: Roman Atwood
# screen_name: RomanAtwood
# description: Family First. Smile More :)  https://t.co/R2ncZJQJNK
# statuses_count: 7140
# friends_count: 9037
# followers_count: 2930453
# Account age (in days): 3096
# Average tweets per day: 2.31
# Most mentioned Twitter users:
# _little_britt_	318
# SmileMoreStore	135
# RomanAtwood	115
# YouTube	66
# GFuelEnergy	29
# JoshSmithActor	28
# KEEMSTAR	25
# mariamsheddo	23
# ChloeDonald_	17
# CouRageJD	10
# Most used hashtags:
# ShortyAwards	8
# SmileMore	6
# RomansNewPrank	6
# NaturalBornPranksters	5
# smilemore	4
# playlistlive	3
# FridayFortnite	2
# Tanked	2
# TeamRoman	2
# tossthetube	2
# All done. Processed 3235 tweets.

# %% [markdown]
# # Machine Learning Model

# %% [markdown]
# ## Preprocessing

# %%
from sklearn import preprocessing as pp
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import stopwords
from tokenize import generate_tokens
import numpy as np

def preprocess_statuses(accounts):
    user_statuses = {}
    stemmer = PorterStemmer()
    for target in accounts:
        key = target['name']
        statuses = []
        for status in target['statuses']:
            status = status['text']

            # convert all strings to lowercase
            status = status.lower()
            
            # remove all punctuations  
            status = re.sub('[^\w\s]','',status)
            words = status.split()
            _words = [] # final word list

            for index, word in enumerate(words):
                # remove all stopwords
                if word not in stopwords.words('english'):
                    # if not stopword, lemmatize 
                    _words.append(stemmer.stem(word))

            status = ' '.join(_words)
            statuses.append(status)
        user_statuses[key] = statuses
    return user_statuses

# %% [markdown]
# ## create feature vectors

# %%
def create_feature_matrix(accounts, user_statuses):
    feature_matrix = []
    for target in accounts:
        vector = []
        statuses = user_statuses[target['name']]
        vector.append(insomnia_index(target))
        vector.append(avg_sentiment(statuses))
        vector.append(first_person(statuses))
        vector.append(tsugawa_terms(statuses))
        vector.append(retweet_rate(target))
        vector.append(url(target))
        word_char_lengths = num_word_char(statuses)
        vector.append(word_char_lengths[0])
        vector.append(word_char_lengths[1])
        vector.extend(usertags(target))
        feature_matrix.append(vector)
    
    return feature_matrix
        

def insomnia_index(target):
    neg_count = 0
    pos_count = 0
    for status in target['statuses']:
        time = status['created_at']
        if time > 9:
            neg_count += 1
        else:
            pos_count += 1
    
    index = (neg_count - pos_count) / len(target['statuses'])
    return index

def avg_sentiment(statuses):
    avg = 0
    for status in statuses:
        blob = TextBlob(status)
        sentiment = blob.sentiment.polarity
        avg += sentiment
    avg_sentiment = avg / len(statuses)
    return avg_sentiment

def first_person(statuses):
    count = 0
    first_person = ["i", "i'd", "i'll", "i'm", "i've", "me", "my"]
    for status in statuses:
        text = status.split()
        for word in first_person:
            count += text.count(word)   
    return count / len(statuses)

def tsugawa_terms(statuses):
    tsugawa_terms = ["even if", "low fever", "very", "workplace", "hopeless", "disappear", "too much", "sickness", "bad", "hospital"]
    count = 0
    count_per_tweet = 0
    for status in statuses:
        for term in tsugawa_terms:
            count += status.count(term)
    return count / len(statuses)

def retweet_rate(target):
    retweet_rate = 0
    for status in target['statuses']:
        if status['retweeted'] == True:
            retweet_rate += 1

    retweet_rate = retweet_rate / len(target['statuses'])
    return retweet_rate

def url(target):
    avg_urls = 0
    for status in target['statuses']:
        avg_urls += len(status['entities']["urls"])
    
    avg_urls = avg_urls / len(target['statuses'])
    return avg_urls

def num_word_char(statuses):
    num_char = 0
    num_words = 0
    for status in statuses:
        num_words += len(status.split())
        num_char += len(status)
    
    num_words = num_words / len(statuses)
    num_char = num_char / len(statuses)
    return num_words, num_char

def usertags(target):
    account_age_days = target['Account_age(in_days)']
    avg_usertags = 0
    avg_urls = 0
    set_usertags = set()
    for status in target['statuses']:
        for user in status['entities']["user_mentions"]:
            set_usertags.add(user["screen_name"])

        avg_usertags += len(status['entities']["user_mentions"])

    avg_usertags_per_day = avg_usertags / float(account_age_days)
    avg_usertags = avg_usertags / len(target['statuses'])

    avg_unique_usertags = len(set_usertags) / len(target['statuses'])
    avg_unique_usertags_per_day = len(set_usertags) / float(account_age_days)
    return avg_usertags, avg_usertags_per_day, avg_unique_usertags, avg_unique_usertags_per_day

# %%
D_all_twitter_data = aggregated_tweet_data_selected.values()
processed_D_statuses = preprocess_statuses(D_all_twitter_data)
D_train_data = create_feature_matrix(D_all_twitter_data, processed_D_statuses)
print(len(D_train_data))
# Out:
# 12

# %%
ND_all_twitter_data = ND_aggregated_tweet_data_selected.values()
processed_D_statuses = preprocess_statuses(ND_all_twitter_data)
ND_train_data = create_feature_matrix(ND_all_twitter_data, processed_D_statuses)
print(len(ND_train_data))
# Out:
# 60

# %% [markdown]
# Appending Depressed and Non-Depressed dataset

# %%
X = D_train_data + ND_train_data
y = [0] * len(D_train_data) + [1] * len(ND_train_data)

# %%
#split training data into train and test sets
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import itertools

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# apply naive bayes model
from sklearn.naive_bayes import GaussianNB

clf = GaussianNB()
clf.fit(X_train, y_train)
score = clf.score(X_test, y_test)
pred = clf.predict(X_test)

# Compute confusion matrix
cm_NB = confusion_matrix(y_test, pred)
print(score, cm_NB)
# Out:
# 0.8333333333333334 [[ 1  4]
#  [ 0 19]]

# %%
# apply SVM model
from sklearn import svm

clf = svm.SVC()
clf.fit(X_train, y_train)
score = clf.score(X_test, y_test)
pred = clf.predict(X_test)

# Compute confusion matrix
cm_SVM = confusion_matrix(y_test, pred)
print(score, cm_SVM)
# Out:
# 0.7916666666666666 [[ 0  5]
#  [ 0 19]]
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
# apply KNN model
from sklearn.neighbors import KNeighborsClassifier

neigh = KNeighborsClassifier(n_neighbors=9)
neigh.fit(X_train, y_train)
score = neigh.score(X_test, y_test)
pred = neigh.predict(X_test)

# Compute confusion matrix
cm_KNN = confusion_matrix(y_test, pred)
print(score, cm_KNN)
# Out:
# 0.7916666666666666 [[ 0  5]
#  [ 0 19]]

# %%
# apply random forest model
from sklearn.ensemble import RandomForestClassifier

clf=RandomForestClassifier(n_estimators=12)
clf.fit(X_train, y_train)
score = clf.score(X_test, y_test)
pred = clf.predict(X_test)

# Compute confusion matrix
cm_RF = confusion_matrix(y_test, pred)
print(score, cm_RF)
# Out:
# 0.7916666666666666 [[ 0  5]
#  [ 0 19]]

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=0)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
class_names = ['depressed', 'non-depressed']

# Plot confusion matrix for Naive Bayes
plt.figure()
plot_confusion_matrix(cm_NB, classes=class_names, normalize=True, 
                      title='Confusion matrix for Naive Bayes')

# Plot confusion matrix for SVM
plt.figure()
plot_confusion_matrix(cm_SVM, classes=class_names, normalize=True,
                      title='Confusion matrix for SVM')

# Plot confusion matrix for KNN
plt.figure()
plot_confusion_matrix(cm_KNN, classes=class_names, normalize=True,
                      title='Confusion matrix for KNN')

# Plot confusion matrix for RF
plt.figure()
plot_confusion_matrix(cm_RF, classes=class_names, normalize=True,
                      title='Confusion matrix for Random Forest')

plt.show()
# Out:
# Normalized confusion matrix
# [[0.         1.        ]
#  [0.27272727 0.72727273]]
# Normalized confusion matrix
# [[0. 1.]
#  [0. 1.]]
# Normalized confusion matrix
# [[0. 1.]
#  [0. 1.]]
# Normalized confusion matrix
# [[0.25       0.75      ]
#  [0.09090909 0.90909091]]

# %%
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True
